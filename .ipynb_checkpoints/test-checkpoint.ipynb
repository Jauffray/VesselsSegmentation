# %%
import torch
import os

# %%
PATH_TO_DATA = '../data/DRIVE/'

# %%
PATH_IMS = PATH_TO_DATA + 'drive_train_images/'
PATH_GT = PATH_TO_DATA + 'train_1st_manual/'

# %%
im_list = os.listdir(PATH_IMS)
gt_list = os.listdir(PATH_GT)

# %%
from PIL import Image

# %%
import os.path as osp

# %%
from torchvision import transforms as tr
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader

# %%
class VesselsDataset(Dataset):
    def __init__(self, img_dir, gt_dir, transforms=None):
        self.img_dir = img_dir
        self.gt_dir = gt_dir
        self.img_names = sorted(os.listdir(self.img_dir))
        self.gt_names = sorted(os.listdir(self.gt_dir))
        self.transforms = transforms

    def __getitem__(self, index):
        img = Image.open(osp.join(self.img_dir, self.img_names[index]))
        gt = Image.open(osp.join(self.gt_dir, self.gt_names[index]))
        if self.transforms is not None:
            img = self.transforms(img)
            gt = self.transforms(gt)

        return img, gt

    def __len__(self):
        return len(self.img_names)

# %%
# from dataloader import VesselsDataset_fromfile
# my_dataset_from_file = VesselsDataset_fromfile(PATH_IMS, PATH_GT, transforms = tr.Compose([resz, to_tensor]))

# %%
resz = tr.Resize([512,512])
to_tensor = tr.ToTensor()

# %%
my_dataset = VesselsDataset(PATH_IMS, PATH_GT, transforms = tr.Compose([resz, to_tensor]))
# if you use pretrained model, you want to use tr.Normalize(mean, std)

# %%
type(my_dataset[10][0])
# Out:
# torch.Tensor

# %%
my_dataset[10][0].shape, my_dataset[10][1].shape
# Out:
# (torch.Size([3, 512, 512]), torch.Size([1, 512, 512]))

# %%
my_loader = DataLoader(dataset=my_dataset,
                        batch_size=2, num_workers=4, shuffle=True)

# %%
my_first_batch = next(iter(my_loader))

# %%
from whatever import add_numbers

# %%
add_numbers(1,23)
# Out:
# 24

# %%
my_first_batch[0].shape, my_first_batch[1].shape
# Out:
# (torch.Size([2, 3, 512, 512]), torch.Size([2, 1, 512, 512]))

# %% [markdown]
# # The model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True):
        super(up, self).__init__()

        #  would be a nice idea if the upsampling could be learned too,
        #  but my machine do not have enough memory to handle all those weights
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, (diffX // 2, diffX - diffX//2,
                        diffY // 2, diffY - diffY//2))
        
        # for padding issues, see 
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
# full assembly of the sub-parts to form the complete net

import torch.nn.functional as F


class UNet(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(UNet, self).__init__()
        self.inc = inconv(n_channels, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256)
        self.up2 = up(512, 128)
        self.up3 = up(256, 64)
        self.up4 = up(128, 64)
        self.outc = outconv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)
        return F.sigmoid(x)

# %%
my_unet = UNet(n_channels = 3, n_classes=1)

# %%
# %timeit model_output = my_unet(my_first_batch[0])
# Out:
# /home/agaldran/anaconda3/envs/histo/lib/python3.7/site-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# /home/agaldran/anaconda3/envs/histo/lib/python3.7/site-packages/torch/nn/functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 7.03 s ± 109 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_unet.cuda();

# %%
next(my_unet.parameters()).is_cuda
# Out:
# True

# %%
model_output = my_unet(my_first_batch[0].cuda())

# %%
# %timeit model_output = my_unet(my_first_batch[0].cuda())

# %%
import torch.optim as optim
optimizer = optim.SGD(my_unet.parameters(), lr=0.001, momentum=0.9)

# %%
criterion = nn.BCELoss()

# %%
nr_epochs = 20

# %%
from tqdm import tqdm_notebook as tqdm

# %%
my_unet.eval();

# %%
my_unet.train();

# %%
for epoch in range(nr_epochs):  # loop over the dataset multiple times
    # train
    my_unet.train()
    running_loss = 0.0
    for i, batches in tqdm(enumerate(my_loader)):
        # get the inputs; data is a list of [inputs, labels]
        image_batch, labels_batch = batches
        image_batch, labels_batch  =image_batch.cuda(), labels_batch.cuda()
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs_batch = my_unet(image_batch)
        loss = criterion(outputs_batch, labels_batch)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2 == 0:
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss/2))
            running_loss = 0.0
    # end of epoch
    
    # val
    my_unet.eval()
    for i, batches in tqdm(enumerate(val_loader)):
        # get the inputs; data is a list of [inputs, labels]
        image_batch, labels_batch = batches
        image_batch, labels_batch = image_batch.cuda(), labels_batch.cuda()

        # forward + backward + optimize
        outputs_batch = my_unet(image_batch)
        loss = criterion(outputs_batch, labels_batch)

        # print statistics
        running_loss += loss.item()
        if i % 2 == 0:
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss/2))
            running_loss = 0.0
print('Finished Training')
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# [1,     1] loss: 0.096
# [1,     3] loss: 0.190
# [1,     5] loss: 0.191
# [1,     7] loss: 0.194
# [1,     9] loss: 0.202
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# [2,     1] loss: 0.100
# [2,     3] loss: 0.185
# [2,     5] loss: 0.184
# [2,     7] loss: 0.186
# [2,     9] loss: 0.200
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# [3,     1] loss: 0.091
# [3,     3] loss: 0.190
# [3,     5] loss: 0.180
# [3,     7] loss: 0.186
# [3,     9] loss: 0.192
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
#